# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample-data.csv")
df.set_index("Date", inplace = True)
df
# Out:
#            Earning(dollars)            Job  Travelled(km)
# Date
# 7/9/2024               35.0         Garage           25.0
# 7/10/2024               NaN            NaN           30.0
# 7/11/2024              40.0           Taxi            NaN
# 7/12/2024              35.0            NaN            NaN
# 7/13/2024               5.0  Sold-Icecream           50.0
# 7/14/2024               NaN            NaN            NaN
# 7/15/2024               NaN            NaN           60.0
# 7/16/2024              35.0         Garage           70.0
# 7/17/2024               NaN            NaN            NaN
# 7/18/2024              40.0            NaN            NaN

# %%
new_df = df.fillna({
    'Earning(dollars)': 0,
    'Job': "Nothing",
    "Travelled(km)":0
})
new_df
# Out:
#            Earning(dollars)            Job  Travelled(km)
# Date
# 7/9/2024               35.0         Garage           25.0
# 7/10/2024               0.0        Nothing           30.0
# 7/11/2024              40.0           Taxi            0.0
# 7/12/2024              35.0        Nothing            0.0
# 7/13/2024               5.0  Sold-Icecream           50.0
# 7/14/2024               0.0        Nothing            0.0
# 7/15/2024               0.0        Nothing           60.0
# 7/16/2024              35.0         Garage           70.0
# 7/17/2024               0.0        Nothing            0.0
# 7/18/2024              40.0        Nothing            0.0

# %%
new_df = df.fillna(method = 'ffill')
new_df
# Out:
# <ipython-input-10-98ca3f70b779>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = 'ffill')
#            Earning(dollars)            Job  Travelled(km)
# Date
# 7/9/2024               35.0         Garage           25.0
# 7/10/2024              35.0         Garage           30.0
# 7/11/2024              40.0           Taxi           30.0
# 7/12/2024              35.0           Taxi           30.0
# 7/13/2024               5.0  Sold-Icecream           50.0
# 7/14/2024               5.0  Sold-Icecream           50.0
# 7/15/2024               5.0  Sold-Icecream           60.0
# 7/16/2024              35.0         Garage           70.0
# 7/17/2024              35.0         Garage           70.0
# 7/18/2024              40.0         Garage           70.0

# %%
new_df = df.fillna(method = 'bfill')
new_df
# Out:
# <ipython-input-11-624226e5e8fd>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = 'bfill')
#            Earning(dollars)            Job  Travelled(km)
# Date
# 7/9/2024               35.0         Garage           25.0
# 7/10/2024              40.0           Taxi           30.0
# 7/11/2024              40.0           Taxi           50.0
# 7/12/2024              35.0  Sold-Icecream           50.0
# 7/13/2024               5.0  Sold-Icecream           50.0
# 7/14/2024              35.0         Garage           60.0
# 7/15/2024              35.0         Garage           60.0
# 7/16/2024              35.0         Garage           70.0
# 7/17/2024              40.0            NaN            NaN
# 7/18/2024              40.0            NaN            NaN
